# %% [markdown]
# #Tarea 8
# ##Terminar de implementar los métodos de la lista doblemente ligada
# ![image.png](data:image/png;base64,...)

# %%
class NodoDoble:
    def __init__( self , value , siguiente = None , previo = None ):
        self.data = value
        self.next = siguiente
        self.prev = previo

# %%
class DoubleLinkedList:
    def __init__( self  ):
        self.head = None
        self.tail = None
        self.size = 0

    def get_size( self ):
        if self.size == 0:
            print ('La lista está vacía y por lo tanto no tiene tamaño')
        else:
            print( f'La lista tiene {self.size} elementos')

    def get_size2( self ):
        return self.size
    
    def is_empty( self ): # true si la lista está vacía
        return self.size == 0

    def append( self , value ):
        if self.is_empty():
            self.head = NodoDoble( value)
            self.tail = self.head
        else:
            self.tail.next = NodoDoble(value , None , self.tail )
            self.tail = self.tail.next
        self.size += 1

    def find_from_tail( self , value ):# --> buscar a partir de tail y regresar la posición
        curr_node = self.tail
        while curr_node.data != value:
            curr_node = curr_node.prev  
        if curr_node.data == value:
            print('El valor %s se encontró y está en la posicion %s' %(value,value))
        

    def find_from_head( self , value ):
        curr_node = self.head
        while curr_node.data != value:
            curr_node = curr_node.next
        if curr_node.data == value:
            print('El valor %s se encontró y está en la posicion %s' %(value,value))

    def remove_from_tail( self , value  ): # --> elimina a partir de tail
        curr_node = self.tail
        while curr_node.data != value:
            curr_node = curr_node.prev

        if curr_node.data == value:
            curr_node.next.prev = curr_node.prev
            curr_node.prev.next = curr_node.next
        self.size -= 1

    def remove_from_head( self , value  ): # --> elimina a partir de head
        curr_node = self.head
        while curr_node.data != value:
            curr_node = curr_node.next

        if curr_node.data == value:
            curr_node.prev.next = curr_node.next
            curr_node.next.prev = curr_node.prev
        self.size -= 1
    
    def transversal( self ):
        curr_node = self.head
        while curr_node != None :
            print(f"| {curr_node.data} | --> ", end="")
            curr_node = curr_node.next
        print("")

    def reverse_transversal( self ):
        curr_node = self.tail
        while curr_node != None:
            print(f"| {curr_node.data} | --> ", end="")
            curr_node = curr_node.prev
        print("")

# %%
#Probando los métodos
ldl = DoubleLinkedList()

#Get Size
print(f'Probando Get Size')
print(ldl.get_size())

#Is Empty
ldl.is_empty()

#Append
ldl.append(1)
ldl.append(2)
ldl.append(3)
ldl.append(4)
ldl.append(5)
ldl.append(6)



#Find from tail
print(f'\nProbando find from tail')
ldl.find_from_tail(4)

#Find from head
print(f'\nProbando find from head')
ldl.find_from_head(3)



print('\n')
ldl.transversal()

#Remove from tail
ldl.remove_from_tail (4)
print(f'\nDespués del remove from tail con 40')
ldl.transversal()

#Remove from head
ldl.remove_from_head(3)
print(f'\nDespués del remove from head con 30')
ldl.transversal()

#Transversal
print(f'\nProbando Transversal')
ldl.transversal()

#Reverse Transversal
print(f'\nProbando Reverse Transversal')
ldl.reverse_transversal()
# Out:
# Probando Get Size
# La lista está vacía y por lo tanto no tiene tamaño
# None
#
# Probando find from tail
# El valor 4 se encontró y está en la posicion 4
#
# Probando find from head
# El valor 3 se encontró y está en la posicion 3
#
#
# | 1 | --> | 2 | --> | 3 | --> | 4 | --> | 5 | --> | 6 | -->
#
# Después del remove from tail con 40
# | 1 | --> | 2 | --> | 3 | --> | 5 | --> | 6 | -->
#
# Después del remove from head con 30
# | 1 | --> | 2 | --> | 5 | --> | 6 | -->
#
# Probando Transversal
# | 1 | --> | 2 | --> | 5 | --> | 6 | -->
#
# Probando Reverse Transversal
# | 6 | --> | 5 | --> | 2 | --> | 1 | -->
